# %% [markdown]
# # Decision Tree Regression

# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Importing the dataset

# %%
dataset = pd.read_csv('Position_Salaries.csv')
X = dataset.iloc[:, 1:-1].values #we are using only one independent variable but it can be adapted for multiple variables
y = dataset.iloc[:, -1].values
#check if there are misssing data or categorical data and preprocess them
#you can split dataset into train and test
#we DON'T apply feature scaling in Decision Trees

# %% [markdown]
# ## Training the Decision Tree Regression model on the whole dataset

# %%
from sklearn.tree import DecisionTreeRegressor #not DecisionTreeClassifier
#DecisionTreeRegressor predicts a continuous numerical value
#DecisionTreeClassifier predicts a category
regressor = DecisionTreeRegressor(random_state = 0)#no need tuning inner parameters now]
regressor.fit(X,y)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=0, splitter='best')

# %% [markdown]
# ## Predicting a new result

# %%
regressor.predict([[6.5]])#not a good prediction because we have only one independent variable
# Out:
# array([150000.])

# %% [markdown]
# ## Visualising the Decision Tree Regression results (higher resolution)

# %%
X_grid = np.arange(min(X), max(X), 0.01)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X, y, color = 'red')
plt.plot(X_grid, regressor.predict(X_grid), color = 'blue')
plt.title('Truth or Bluff (Decision Tree Regression)')
plt.xlabel('Position level')
plt.ylabel('Salary')
plt.show()

# %%
#just trying sth out
plt.scatter(X,y)
plt.plot(X, regressor.predict(X))#prediction makes use of decision tree regressor
plt.show()
